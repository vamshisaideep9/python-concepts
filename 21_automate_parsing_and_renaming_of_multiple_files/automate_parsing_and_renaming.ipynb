# %%
import os

# %%
print(os.getcwd())
# Out:
# c:\Users\vamsh\OneDrive\Desktop\Python Concepts (A to Z)\Python-Concepts-A-to-Z-by-CoreySchefer\21_automate_parsing_and_renaming_of_multiple_files

# %%
os.chdir('c:/Users/vamsh/Downloads/')

# %%
print(os.listdir())
# Out:
# ['000a', '000a.zip', '06-18 Part2 Car Trouble.mp3', '1.png', '2.png', '424550637_2354750288050694_3659277550496482671_n.heic', 'aadhar back.jpeg', 'aadhar front.jpeg', 'adult.csv', 'Advance SQL Demo rec.sql', 'align-justify.png', 'An--d9mpiTEqP6C7thazWz-6i11c2pc087PuXKyYx_LCemun1BMojTJOB3kH91c4RmFu_PURKBo-TnPSM3nzAmH2.mp4', 'Anaconda3-2024.10-1-Windows-x86_64.exe', 'application statuspng.png', 'archive', 'archive (1)', 'archive (1).zip', 'archive (2)', 'archive (2).zip', 'archive.zip', 'ATS - Functional Specification Requirement.docx', 'ATS DESIGN DOCUMENT.docx', 'bhp.csv', 'Black Minimal Motivation Quote LinkedIn Banner', 'Black Minimal Motivation Quote LinkedIn Banner.zip', 'Britney-pranks.mp3', 'c43dc9656d6746500b02040d9cea73ad.jpg', 'cat_and_dog (1).jpg', 'cat_and_dog (1).png', 'cat_and_dog.jpg', 'cherry.png', 'chromedriver_win32', 'chromedriver_win32.zip', 'client.py', 'client_secret_485396226794-cubr2qlatk507n2hgesbdphkt0l2s3kn.apps.googleusercontent.com.json', 'client_secret_5
# ...

# %%
for f in os.listdir():
    print(f)
# Out:
# 000a
# 000a.zip
# 06-18 Part2 Car Trouble.mp3
# 1.png
# 2.png
# 424550637_2354750288050694_3659277550496482671_n.heic
# aadhar back.jpeg
# aadhar front.jpeg
# adult.csv
# Advance SQL Demo rec.sql
# align-justify.png
# An--d9mpiTEqP6C7thazWz-6i11c2pc087PuXKyYx_LCemun1BMojTJOB3kH91c4RmFu_PURKBo-TnPSM3nzAmH2.mp4
# Anaconda3-2024.10-1-Windows-x86_64.exe
# application statuspng.png
# archive
# archive (1)
# archive (1).zip
# archive (2)
# archive (2).zip
# archive.zip
# ATS - Functional Specification Requirement.docx
# ATS DESIGN DOCUMENT.docx
# bhp.csv
# Black Minimal Motivation Quote LinkedIn Banner
# Black Minimal Motivation Quote LinkedIn Banner.zip
# Britney-pranks.mp3
# c43dc9656d6746500b02040d9cea73ad.jpg
# cat_and_dog (1).jpg
# cat_and_dog (1).png
# cat_and_dog.jpg
# cherry.png
# chromedriver_win32
# chromedriver_win32.zip
# client.py
# client_secret_485396226794-cubr2qlatk507n2hgesbdphkt0l2s3kn.apps.googleusercontent.com.json
# ...

# %%
for f in os.listdir():
    file_name, file_ext = os.path.splitext(f)
    print(file_name.split('-'))
# Out:
# ['000a']
# ['000a']
# ['06', '18 Part2 Car Trouble']
# ['1']
# ['2']
# ['424550637_2354750288050694_3659277550496482671_n']
# ['aadhar back']
# ['aadhar front']
# ['adult']
# ['Advance SQL Demo rec']
# ['align', 'justify']
# ['An', '', 'd9mpiTEqP6C7thazWz', '6i11c2pc087PuXKyYx_LCemun1BMojTJOB3kH91c4RmFu_PURKBo', 'TnPSM3nzAmH2']
# ['Anaconda3', '2024.10', '1', 'Windows', 'x86_64']
# ['application statuspng']
# ['archive']
# ['archive (1)']
# ['archive (1)']
# ['archive (2)']
# ['archive (2)']
# ['archive']
# ['ATS ', ' Functional Specification Requirement']
# ['ATS DESIGN DOCUMENT']
# ['bhp']
# ['Black Minimal Motivation Quote LinkedIn Banner']
# ['Black Minimal Motivation Quote LinkedIn Banner']
# ['Britney', 'pranks']
# ['c43dc9656d6746500b02040d9cea73ad']
# ['cat_and_dog (1)']
# ['cat_and_dog (1)']
# ['cat_and_dog']
# ['cherry']
# ['chromedriver_win32']
# ['chromedriver_win32']
# ['client']
# ...
